# %% [markdown]
# <a href="https://colab.research.google.com/github/jorgecaraveobalderas-beep/Class-Files/blob/main/Archivo%20de%20prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejemplo de codigo

# %%
print("Hola hola")
# Out:
# Hola hola

# %%
print("Hola que tal")
# Out:
# Hola que tal
