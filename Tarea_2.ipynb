# %% [markdown]
# <a href="https://colab.research.google.com/github/jorgecaraveobalderas-beep/Class-Files/blob/Class_Week_1/Tarea_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Práctica 2: Expresiones Regulares**

# %% [markdown]
# ***En esta practica, se te pide que diseñes un código en Google Colab para analizar el archivo informe_acciones.txt. El archivo contiene varios correos electrónicos en donde se informa el valor de las acciones de diferentes empresas***

# %% [markdown]
# ***Introduccion: Subir archivo y conectar Drive***
#
# ---

# %%
import re
from google.colab import drive
drive.mount('/content/drive')

Archivo = open('/content/drive/MyDrive/ClassFiles/Clase 1/informe_acciones.txt', encoding='latin-1')
for linea in Archivo:
  print(linea)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#
#
# Te escribo para informarte sobre el valor actual de la acción de Visa Inc. (V).
#
# Fecha: 2024-09-02 12:34:26
#
# Valor actual: $1140.93
#
#
#
# Saludos,
#
# Equipo de Mercado
#
#
#
# ----------------------------------------
#
#
#
# De: mercado@acciones.com
#
# Para: inversor@ejemplo.com
#
# Asunto: Informe de Acción - INTC
#
#
#
# Hola,
#
#
#
# Te escribo para informarte sobre el valor actual de la acción de Intel Corporation (INTC).
#
# Fecha: 2024-09-02 12:34:26
#
# Valor actual: $735.01
#
#
#
# Saludos,
#
# Equipo de Mercado
#
#
#
# ----------------------------------------
#
#
#
# De: mercado@acciones.com
#
# Para: inversor@ejemplo.com
#
# Asunto: Informe de Acción - ORCL
#
#
#
# Hola,
#
#
#
# Te escribo para informarte sobre el valor actual de la acción de Oracle Corporation (ORCL).
#
# Fecha: 2024-09-02 12:34:26
#
# Valor actual: $153.06
#
#
#
# Saludos,
#
# Equipo de Mercado
#
#
#
# ...

# %% [markdown]
# ***El código deberá extraer el valor actual de las acciones que aparecen en cada correo electrónico e imprimirlo a pantalla. En este ejercicio debeás utilizar Expresiones Regulares***

# %%
Archivo = open('/content/drive/MyDrive/ClassFiles/Clase 1/informe_acciones.txt', encoding='latin-1')
for linea in Archivo:
    linea = linea.rstrip()
    x = re.findall(r'^Valor actual:\s*\$([0-9]+\.[0-9]{2})', linea)
    if len(x) > 0:
        print(x)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# ['363.55']
# ['817.85']
# ['150.21']
# ['1192.46']
# ['475.52']
# ['1084.16']
# ['1482.44']
# ['457.12']
# ['1297.71']
# ['1156.54']
# ['445.78']
# ['599.31']
# ['296.27']
# ['1414.16']
# ['959.02']
# ['489.46']
# ['307.49']
# ['500.67']
# ['428.31']
# ['1087.21']
# ['609.14']
# ['509.24']
# ['756.45']
# ['970.71']
# ['1453.62']
# ['649.24']
# ['299.27']
# ['1340.96']
# ['497.43']
# ['1073.84']
# ['1123.88']
# ['551.14']
# ['266.08']
# ['1365.53']
# ['1410.54']
# ['1093.59']
# ['190.71']
# ['727.36']
# ['1489.73']
# ['800.34']
# ['1432.73']
# ['273.95']
# ['913.11']
# ['1122.26']
# ['527.18']
# ['648.44']
# ['654.82']
# ['1268.12']
# ['620.01']
# ['542.73']
# ['1467.93']
# ['1348.81']
# ['303.45']
# ['1010.88']
# ['249.86']
# ['939.34']
# ['561.54']
# ['379.77']
# ['1255.14']
# ['1383.07']
# ['1040.88']
# ['788.58']
# ['919.65']
# ['164.45']
# ['1225.21']
# ['957.97']
# ['1212.68']
# ['450.14']
# ['309.35']
# ...

# %%
Archivo.close()
